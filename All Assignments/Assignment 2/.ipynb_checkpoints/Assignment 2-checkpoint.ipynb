# %% [markdown]
# Scenario 1: Grocery Shopping List
# You are creating a program to manage a grocery shopping list. Users should be able to add items,
# remove items, and display the current list.

# %%
grocery_shopping_list = []

grocery_shopping = input("Enter your items, Put comma(,) after each item): ").split(",")
for each_item in grocery_shopping:
    grocery_shopping_list.append(each_item)

recheck_grocery_list = input("\nDo you want to delete any item(s) from the list (Y/N): ")

if recheck_grocery_list == 'Y':
    remove_items_list = []
    remove_items = input("\nEnter the items you wish to remove from the Grocery Shopping List,\
 Put comma(,) after each item if more than one item: ").split(",")
    for each_item in remove_items:
        remove_items_list.append(each_item)
        for item in remove_items_list:
            if item in grocery_shopping_list:
                grocery_shopping_list.remove(item)
            else:
                print(f"\n{remove_items_list} is not in the list.")                  
else:
    print(_)
    
print(f"\nThe Grocery Shopping List has Items in it as follows:\n{grocery_shopping_list}")
# Out:
# Enter your items, Put comma(,) after each item): Mango,Orange,Peach,Pomegranate,Pear
#
# Do you want to delete any item(s) from the list (Y/N): Y
#
# Enter the items you wish to remove from the Grocery Shopping List, Put comma(,) after each item if more than one item: Peach
#
# The Grocery Shopping List has Items in it as follows:
# ['Mango', 'Orange', 'Pomegranate', 'Pear']

# %% [markdown]
# Scenario 2: Student Grades
# You are managing student grades using a dictionary. You need to calculate the average grade.take
# atleast 5 Students grades & then calculate the average.

# %%
student_grades = {
    "Muhammad": [90, 65, 75],
    "Muzammil": [84, 87, 69],
    "Hamza": [59, 83, 75],
    "Ali": [35, 94, 79],
    "Qasim": [89, 80, 85],
}

sum_total_grades = 0
len_total_subjects = 0

for grades in student_grades.values():
    sum_total_grades += sum(grades)
    len_total_subjects += len(grades)

student_average_grade = sum_total_grades / len_total_subjects

print(f"Average Grade Of Students: {student_average_grade}")
# Out:
# Average Grade Of Students: 76.6

# %% [markdown]
# Scenario 3: Word Frequency Counter
# You are given a list of words, and you need to count the frequency of each word.
#
# word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

# %%
word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

word_freq = {}

for word in word_list:
    if word in word_freq:
        word_freq[word] += 1
    else:
        word_freq[word] = 1

print("Words : Frequency")
for word, freq in word_freq.items():
    print(f"{word} : {freq}")
# Out:
# Words : Frequency
# apple : 3
# banana : 2
# orange : 1
# grape : 1

# %% [markdown]
# Scenario 3: Password Strength Checker
# You are creating a program to check the strength of passwords based on certain criteria.
#
# • Password should be at least 8 characters long.
#
# • Password should contain at least one digit.
#
# • Password should contain at least one letter

# %%
password = input("Enter Password: ")

if len(password) < 8:
    print("Password should be at least 8 characters long.")

if not any(char.isdigit() for char in password):
    print("Password should contain at least one digit.")

if not any(char.isalpha() for char in password):
    print("Password should contain at least one letter.")

else:
    print(f"\n'{password}' has been set as Password!")
    print("Strong Password : Password meets all criteria.")
# Out:
# Enter Password: W12345678
#
# 'W12345678' has been set as Password!
# Strong Password : Password meets all criteria.

# %% [markdown]
# Scenario 04: Voting System (Annual Employee Recognition Awards)
#
# You are developing a simple voting system for a contest. Users can vote for their Favorite option, and
# you need to count the votes.
#
# In a corporate setting, the HR department is organizing the Annual Employee Recognition Awards,
# where employees get the opportunity to vote for their colleagues nominated in different categories.
# The HR team has decided to use a simple voting system to collect and tally votes for the nominees in
# various award categories. The script provided will be utilized for this purpose.
#
# Candidates: The nominees for different award categories, such as "Employee of the Year," "Team
# Player of the Year," and "Innovation Award," are represented by the list of candidates: 'Candidate A,'
# 'Candidate B,' and 'Candidate C.'
#
# Voting Process: Employees are requested to input the number of voters participating in the awards.
# Each voter is presented with a list of nominees, and they can vote for their preferred candidate by
# entering the corresponding number.
#
# Validation: The script ensures that the entered vote is within the valid range of candidates. If an
# employee enters an invalid vote, the system prompts them to choose a valid candidate.
#
# Recording Votes: The script records each vote for the selected candidate and prints a confirmation
# message indicating that the vote has been recorded.
#
# Results Display: Once all votes are collected, the system displays the voting results, showing the
# number of votes each candidate received in each category.
#
# Award Winners: Based on the voting results, the HR department can identify the winners for each
# award category and proceed with recognizing and rewarding the selected employees during the
# Annual Employee Recognition Ceremony.
#
# This script provides a straightforward and transparent way for employees to participate in the
# recognition process, fostering a sense of engagement and community within the organization. The
# HR team can use the collected votes to acknowledge and appreciate the efforts of outstanding
# employees in various aspects of their work.

# %%
num_voters = int(input("Enter the number of voters: "))
print(f"There are {num_voters} voters in total.")

nominees = ["Candidate A", "Candidate B", "Candidate C"]
print("\n<-------------------Voting of Annual Employee Recognition Awards Starts-------------------->")

voted_employee_of_the_year = []
print(f"\n\n<---------------Voting for Employee of the Year Starts---------------->")
for num in range(num_voters):
    print(f"Voter {num+1}:")
    for nominee, candidate in enumerate(nominees, 1):
        print(f"{nominee}.{candidate}")
    nominee_num = int(input("Select preferred candidate by entering the corresponding number: "))
    if 1<= nominee_num <= 3:
        print(f"Voter No. {num+1} vote recorded.\n")
        voted_employee_of_the_year.append(nominee_num)
    else:
        print("Invalid Candidate number.")
print("<-----------------Employee of the Year Voting Ended------------------->")


voted_team_player_of_the_year = []
print(f"\n\n<--------------Voting for Team Player of the Year Starts-------------->")
for num in range(num_voters):
    print(f"Voter {num+1}:")
    for nominee, candidate in enumerate(nominees, 1):
        print(f"{nominee}.{candidate}")
    nominee_num = int(input("Select preferred candidate by entering the corresponding number: "))
    if 1<= nominee_num <= 3:
        print(f"Voter No. {num+1} vote recorded.\n")
        voted_team_player_of_the_year.append(nominee_num)
    else:
        print("Invalid Candidate number.")
print("<----------------Team Player of the Year Voting Ended----------------->")


voted_innovation_award = []
print(f"\n\n<-----------------Voting for Innovation Award Starts------------------>")
for num in range(num_voters):
    print(f"Voter {num+1}:")
    for nominee, candidate in enumerate(nominees, 1):
        print(f"{nominee}.{candidate}")
    nominee_num = int(input("Select preferred candidate by entering the corresponding number: "))
    if 1<= nominee_num <= 3:
        print(f"Voter No. {num+1} vote recorded.\n")
        voted_innovation_award.append(nominee_num)
    else:
        print("Invalid Candidate number.")
print("<-------------------Innovation Award Voting Ended--------------------->")


print("\n<-------------------Voting of Annual Employee Recognition Awards Ended--------------------->")

print(f"\n\n\n<------------------------Results of Annual Employee Recognition Awards-------------------------->")

print(f"\n\nEmployee of the Year\n{nominees[0]} : {voted_employee_of_the_year.count(1)}\n{nominees[1]} : \
{voted_employee_of_the_year.count(2)}\n{nominees[2]} : {voted_employee_of_the_year.count(3)}")

print(f"\n\nTeam Player of the Year\n{nominees[0]} : {voted_team_player_of_the_year.count(1)}\n{nominees[1]} : \
{voted_team_player_of_the_year.count(2)}\n{nominees[2]} : {voted_team_player_of_the_year.count(3)}")

print(f"\n\nInnovation Award\n{nominees[0]} : {voted_innovation_award.count(1)}\n{nominees[1]} : \
{voted_innovation_award.count(2)}\n{nominees[2]} : {voted_innovation_award.count(3)}")
# Out:
# Enter the number of voters: 5
# There are 5 voters in total.
#
# <-------------------Voting of Annual Employee Recognition Awards Starts-------------------->
#
#
# <---------------Voting for Employee of the Year Starts---------------->
# Voter 1:
# 1.Candidate A
# 2.Candidate B
# 3.Candidate C
# Select preferred candidate by entering the corresponding number: 1
# Voter No. 1 vote recorded.
#
# Voter 2:
# 1.Candidate A
# 2.Candidate B
# 3.Candidate C
# Select preferred candidate by entering the corresponding number: 2
# Voter No. 2 vote recorded.
#
# Voter 3:
# 1.Candidate A
# 2.Candidate B
# 3.Candidate C
# Select preferred candidate by entering the corresponding number: 3
# Voter No. 3 vote recorded.
#
# Voter 4:
# 1.Candidate A
# 2.Candidate B
# 3.Candidate C
# Select preferred candidate by entering the corresponding number: 1
# Voter No. 4 vote recorded.
#
# Voter 5:
# 1.Candidate A
# 2.Candidate B
# 3.Candidate C
# ...
